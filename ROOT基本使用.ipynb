# %% [markdown]
# <a href="https://colab.research.google.com/github/YaXun112/Bell2/blob/ROOT/ROOT%E5%9F%BA%E6%9C%AC%E4%BD%BF%E7%94%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %ls
# Out:
# absl/
# absl_py-1.4.0.dist-info/
# accelerate/
# accelerate-0.32.1.dist-info/
# adbc_driver_duckdb/
# aiohappyeyeballs/
# aiohappyeyeballs-2.4.0.dist-info/
# aiohttp/
# aiohttp-3.10.5.dist-info/
# aiosignal/
# aiosignal-1.3.1.dist-info/
# alabaster/
# alabaster-0.7.16.dist-info/
# albucore/
# albucore-0.0.13.dist-info/
# albumentations/
# albumentations-1.4.14.dist-info/
# altair/
# altair-4.2.2.dist-info/
# annotated_types/
# annotated_types-0.7.0.dist-info/
# anyio/
# anyio-3.7.1.dist-info/
# apiclient/
# apt/
# apt_inst.cpython-310-x86_64-linux-gnu.so*
# apt_inst-stubs/
# apt_pkg.cpython-310-x86_64-linux-gnu.so*
# apt_pkg-stubs/
# aptsources/
# argon2/
# argon2_cffi-23.1.0.dist-info/
# _argon2_cffi_bindings/
# argon2_cffi_bindings-21.2.0.dist-info/
# array_record/
# array_record-0.5.1.dist-info/
# arviz/
# arviz-0.18.0.dist-info/
# asn1crypto/
# asn1crypto-1.5.1.dist-info/
# astropy/
# astropy-6.1.2.dist-info/
# astropy_iers_data/
# ...

# %% [markdown]
# # Installing

# %%
# !wget https://github.com/MohamedElashri/ROOT/releases/download/ubuntu/root_v6.28.04_Ubuntu_20.04.zip
# !unzip /content/root_v6.28.04_Ubuntu_20.04.zip
# !apt-get install git dpkg-dev cmake g++ gcc binutils libx11-dev libxpm-dev libxft-dev libxext-dev tar gfortran subversion
# !apt-get inatall libpython3.6-dev
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: root_build/lib/libSessionViewer.so
#   inflating: root_build/lib/libSQLIO.so
#  extracting: root_build/lib/libtbbmalloc.so
#   inflating: root_build/lib/SPlot.pcm
#   inflating: root_build/lib/Gdml.pcm
#   inflating: root_build/lib/libNetxNG.so
#   inflating: root_build/lib/libRHTTP.so
#   inflating: root_build/lib/libc.pcm
#   inflating: root_build/lib/libsetDict.so
#   inflating: root_build/lib/libTMVA.so
#   inflating: root_build/lib/ROOT_Rtypes.pcm
#   inflating: root_build/lib/libcomplexDict.so
#   inflating: root_build/lib/SpectrumPainter.pcm
#   inflating: root_build/lib/libXrdSecgsiGMAPDN-5.so
#   inflating: root_build/lib/libProof.so
#   inflating: root_build/lib/ROOT_Foundation_C.pcm
#   inflating: root_build/lib/libXrdSecpwd-5.so
#   inflating: root_build/lib/libRHTTPSniff.so
#   inflating: root_build/lib/ROOTTMVASofie.pcm
#   inflating: root_build/lib/libmapDict.rootmap
# ...

# %%
# The following is needed because colab upgraded the openssl library
# !wget http://archive.ubuntu.com/ubuntu/pool/main/o/openssl/libssl1.1_1.1.1f-1ubuntu2_amd64.deb
# !sudo dpkg -i libssl1.1_1.1.1f-1ubuntu2_amd64.deb
# Out:
# --2024-09-01 08:44:12--  http://archive.ubuntu.com/ubuntu/pool/main/o/openssl/libssl1.1_1.1.1f-1ubuntu2_amd64.deb
# Resolving archive.ubuntu.com (archive.ubuntu.com)... 91.189.91.82, 185.125.190.81, 185.125.190.82, ...
# Connecting to archive.ubuntu.com (archive.ubuntu.com)|91.189.91.82|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1318204 (1.3M) [application/vnd.debian.binary-package]
# Saving to: ‘libssl1.1_1.1.1f-1ubuntu2_amd64.deb’
#
# libssl1.1_1.1.1f-1u 100%[===================>]   1.26M  4.66MB/s    in 0.3s
#
# 2024-09-01 08:44:12 (4.66 MB/s) - ‘libssl1.1_1.1.1f-1ubuntu2_amd64.deb’ saved [1318204/1318204]
#
# (Reading database ... 123757 files and directories currently installed.)
# Preparing to unpack libssl1.1_1.1.1f-1ubuntu2_amd64.deb ...
# Unpacking libssl1.1:amd64 (1.1.1f-1ubuntu2) over (1.1.1f-1ubuntu2) ...
# Setting up libssl1.1:amd64 (1.1.1f-1ubuntu2) ...
# debconf: unable to initialize frontend: Dialog
# ...

# %%
# !pip install metakernel

# %%
# %ls
# Out:
# absl/
# absl_py-1.4.0.dist-info/
# accelerate/
# accelerate-0.32.1.dist-info/
# adbc_driver_duckdb/
# aiohappyeyeballs/
# aiohappyeyeballs-2.4.0.dist-info/
# aiohttp/
# aiohttp-3.10.5.dist-info/
# aiosignal/
# aiosignal-1.3.1.dist-info/
# alabaster/
# alabaster-0.7.16.dist-info/
# albucore/
# albucore-0.0.13.dist-info/
# albumentations/
# albumentations-1.4.14.dist-info/
# altair/
# altair-4.2.2.dist-info/
# annotated_types/
# annotated_types-0.7.0.dist-info/
# anyio/
# anyio-3.7.1.dist-info/
# apiclient/
# apt/
# apt_inst.cpython-310-x86_64-linux-gnu.so*
# apt_inst-stubs/
# apt_pkg.cpython-310-x86_64-linux-gnu.so*
# apt_pkg-stubs/
# aptsources/
# argon2/
# argon2_cffi-23.1.0.dist-info/
# _argon2_cffi_bindings/
# argon2_cffi_bindings-21.2.0.dist-info/
# array_record/
# array_record-0.5.1.dist-info/
# arviz/
# arviz-0.18.0.dist-info/
# asn1crypto/
# asn1crypto-1.5.1.dist-info/
# astropy/
# astropy-6.1.2.dist-info/
# astropy_iers_data/
# ...

# %% [markdown]
# # Preprocessing

# %%
import sys
sys.path.append("/content/root_build/")
sys.path.append("/content/root_build/bin/")
sys.path.append("/content/root_build/include/")
sys.path.append("/content/root_build/lib/")
import ctypes
ctypes.cdll.LoadLibrary('/content/root_build/lib//libCore.so')
ctypes.cdll.LoadLibrary('/content/root_build/lib//libThread.so')
ctypes.cdll.LoadLibrary('/content/root_build/lib//libTreePlayer.so')
# Out:
# <CDLL '/content/root_build/lib//libTreePlayer.so', handle 5680a994fa30 at 0x7adb3e6e4910>

# %%
# Configuration options
import ROOT
ROOT.PyConfig.DisableRootLogon = True
ROOT.PyConfig.IgnoreCommandLineOptions = False

# %%
# Content of .rootlogon.py
#myStyle = ROOT.TStyle('MyStyle','My graphics style')
#myStyle.SetCanvasColor(ROOT.kWhite) # My canvases are blue!
#ROOT.gROOT.SetStyle('MyStyle')

# %%
# Enabling batch mode
ROOT.gROOT.SetBatch(True)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %ls
# Out:
# absl/
# absl_py-1.4.0.dist-info/
# accelerate/
# accelerate-0.32.1.dist-info/
# adbc_driver_duckdb/
# aiohappyeyeballs/
# aiohappyeyeballs-2.4.0.dist-info/
# aiohttp/
# aiohttp-3.10.5.dist-info/
# aiosignal/
# aiosignal-1.3.1.dist-info/
# alabaster/
# alabaster-0.7.16.dist-info/
# albucore/
# albucore-0.0.13.dist-info/
# albumentations/
# albumentations-1.4.14.dist-info/
# altair/
# altair-4.2.2.dist-info/
# annotated_types/
# annotated_types-0.7.0.dist-info/
# anyio/
# anyio-3.7.1.dist-info/
# apiclient/
# apt/
# apt_inst.cpython-310-x86_64-linux-gnu.so*
# apt_inst-stubs/
# apt_pkg.cpython-310-x86_64-linux-gnu.so*
# apt_pkg-stubs/
# aptsources/
# argon2/
# argon2_cffi-23.1.0.dist-info/
# _argon2_cffi_bindings/
# argon2_cffi_bindings-21.2.0.dist-info/
# array_record/
# array_record-0.5.1.dist-info/
# arviz/
# arviz-0.18.0.dist-info/
# asn1crypto/
# asn1crypto-1.5.1.dist-info/
# astropy/
# astropy-6.1.2.dist-info/
# astropy_iers_data/
# ...

# %%
#%rm

# %% [markdown]
# # [PyROOT](https://root.cern/manual/python/)

# %% [markdown]
# ## Creating file.root

# %%
myFile = ROOT.TFile.Open("myFile.root", "RECREATE")

# %% [markdown]
# ##Math

# %%
ROOT.TMath.Pi()
# Out:
# 3.141592653589793

# %%
ROOT.TMath.Sin(ROOT.TMath.Pi())
# Out:
# 1.2246467991473532e-16

# %%
ROOT.TMath.Cos(ROOT.TMath.Pi())
# Out:
# -1.0

# %%
ROOT.TMath.Exp(1)
# Out:
# 2.718281828459045

# %%
ROOT.gRandom.Rndm()
# Out:
# 0.012823540717363358

# %%
ROOT.gRandom.Rndm()
# Out:
# 0.9425199122633785

# %%
ROOT.gRandom.Gaus()
# Out:
# 1.2138007686428542

# %% [markdown]
# ##Plot

# %%
c = ROOT.TCanvas()
f1 = ROOT.TF1("func1", "sin(x)", 0, 10)
f1.Draw()
c.Draw() # Necessary to make the graphics show!

# %%
# Create a ROOT histogram and draw it
h = ROOT.TH1F("gauss","Example histogram",100,-4,4)
h.FillRandom("gaus")
c = ROOT.TCanvas("myCanvasName","The Canvas Title",800,600)
h.Draw()
c.Draw()

# %% [markdown]
# ##Low-level manipulation of objectsPermalink

# %%
ROOT.gInterpreter.Declare("struct MyStruct { int foo; float bar; };")
# Out:
# False
# input_line_297:1:8: error: redefinition of 'MyStruct'
# struct MyStruct { int foo; float bar; };
#        ^
# input_line_171:1:8: note: previous definition is here
# struct MyStruct { int foo; float bar; };
#        ^

# %%
mys = ROOT.MyStruct()

# %%
ROOT.addressof(mys) # Address of mys' C++ object
# Out:
# 95110859444640

# %%
ROOT.addressof(mys, 'foo') # Address of "foo" field (same as address of object)
# Out:
# 95110859444640

# %%
ROOT.addressof(mys, 'bar') # Address of "bar" field
# Out:
# 95110859444644

# %%
 ROOT.addressof(mys, byref = True) # Address of address of mys' C++ object
# Out:
# 135082061994320

# %% [markdown]
# ##Passing Python callables to C++

# %%
ROOT.gInterpreter.Declare("""
    void call_with_1(const std::function<void(int)> &f) { f(1); }
    """)

def print_arg(x):
    print(x)

ROOT.call_with_1(print_arg)  # prints 1
# Out:
# 1
# input_line_298:2:10: error: redefinition of 'call_with_1'
#     void call_with_1(const std::function<void(int)> &f) { f(1); }
#          ^
# input_line_178:2:10: note: previous definition is here
#     void call_with_1(const std::function<void(int)> &f) { f(1); }
#          ^

# %%
def identity(arr, par):
    return arr[0]

# create an identity function
f = ROOT.TF1('pyf1', identity, -1., 1.)

# plot the function
c = ROOT.TCanvas()
f.Draw()
c.Draw()

# %%
class Linear:
    def __call__(self, arr, par):
        return par[0] + arr[0]*par[1]

# create a linear function with offset 5, and pitch 2
l = Linear()
f = ROOT.TF1('pyf2', l, -1., 1., 2)
f.SetParameters(5., 2.)

# plot the function
c = ROOT.TCanvas()
f.Draw()
c.Draw()

# %% [markdown]
# ##Loading user libraries and Just-In-Time compilation (JITting)

# %%
# Write some C++ code in a string
cpp_code = """
// Function definition
int f(int i) { return i*i; }

// Class definition
class A {
public:
    A() { cout << "Hello PyROOT!" << endl; }
};
"""

# Inject the code in the ROOT interpreter
ROOT.gInterpreter.ProcessLine(cpp_code)

# We find all the C++ entities in Python, right away!
a = ROOT.A()   # prints Hello PyROOT!
x = ROOT.f(3)  # x = 9
print(x)
# Out:
# 9
# Hello PyROOT!

# %% [markdown]
# ##Pythonizing C++ user **classes**

# %%
from ROOT import pythonization

@pythonization("C")
def pythonizor_for_C(klass):
    klass.new_attr = 'New attribute' # injects a new attribute in the class

# %% [markdown]
# ## Instantiation of function templates

# %%
ROOT.gInterpreter.Declare("""
template<typename T> T foo(T arg) { return arg; }
""")
# Out:
# False
# input_line_300:2:24: error: redefinition of 'foo'
# template<typename T> T foo(T arg) { return arg; }
#                        ^
# input_line_213:2:24: note: previous definition is here
# template<typename T> T foo(T arg) { return arg; }
#                        ^

# %%
ROOT.foo['int']  # instantiation
# Out:
# string ::foo(string arg)

# %%
ROOT.foo('int')  # call (auto-instantiation from arg type)
# Out:
# 'int'

# %%
ROOT.std.vector['int'] # instantiation
# Out:
# <class cppyy.gbl.std.vector<int> at 0x5680b37b1fa0>

# %%
ROOT.std.vector('int') # instantiation
# Out:
# <class cppyy.gbl.std.vector<int> at 0x5680b37b1fa0>

# %% [markdown]
# ##Alternative for TPyMultiGenFunction and TPyMultiGradFunction

# %%
from array import array

class MyMultiGenFCN( ROOT.Math.IMultiGenFunction ):
    def NDim( self ):
        return 1

    def DoEval( self, x ):
        return (x[0] - 42) * (x[0] - 42)

    def Clone( self ):
        x = MyMultiGenFCN()
        ROOT.SetOwnership(x, False)
        return x

def main():
    fitter = ROOT.Fit.Fitter()
    myMultiGenFCN = MyMultiGenFCN()
    params = array('d', [1.])
    fitter.FitFCN(myMultiGenFCN, params)
    fitter.Result().Print(ROOT.std.cout, True)

if __name__ == '__main__':
    main()
# Out:
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =   3.0641e-16
# NDf                       =            0
# Edm                       =  6.12819e-16
# NCalls                    =           15
# Par_0                     =           42   +/-   1
#
# Covariance Matrix:
#
#             	       Par_0
# Par_0       	           1
#
# Correlation Matrix:
#
#             	       Par_0
# Par_0       	           1
